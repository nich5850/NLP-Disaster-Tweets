# %% [markdown]
# # NLP Disaster Tweets - Mini Project Report

# %% [markdown]
# This project is based on the Kaggle competition Natural Language Processing with Disaster Tweets.
# We classify whether a tweet refers to a real disaster or not. This notebook documents the entire process from data understanding to model building and evaluation.

# %% [markdown]
# ## Problem and Data Description

# %% [markdown]
# The goal is to identify disaster-related tweets. Tweets are labeled as:
# - `1`: Real disaster
# - `0`: Not a real disaster
#
# The dataset consists of:
# - `train.csv`: Contains labeled tweets used for training.
# - `test.csv`: Contains tweets for testing without labels.
# - `sample_submission.csv`: Format for Kaggle submission.

# %% [markdown]
# ## Exploratory Data Analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

train_df = pd.read_csv("train.csv")

# Check dataset overview
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7613 entries, 0 to 7612
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        7613 non-null   int64
#  1   keyword   7552 non-null   object
#  2   location  5080 non-null   object
#  3   text      7613 non-null   object
#  4   target    7613 non-null   int64
# dtypes: int64(2), object(3)
# memory usage: 297.5+ KB

# %%
# Check class distribution
sns.countplot(data=train_df, x='target')
plt.title('Distribution of Disaster vs Non-Disaster Tweets')
plt.show()

# %%
# Tweet length distribution
train_df['text_length'] = train_df['text'].apply(len)

plt.figure(figsize=(10,6))
sns.histplot(data=train_df, x='text_length', hue='target', bins=30, kde=True)
plt.title('Tweet Length Distribution by Class')
plt.xlabel('Tweet Length')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ## Analysis and Model Training

# %% [markdown]
# Modeling is done in an external Python script `NLPDisaster.py`.
# The script uses TF-IDF vectorization and Logistic Regression for classification.
# You can find the full pipeline including preprocessing, training, and prediction in the script.
#
# After training, a CSV submission file is created for Kaggle using the test dataset.

# %% [markdown]
# ## Results

# %% [markdown]
# After submitting the predictions on Kaggle, we obtained a leaderboard score of **(add your score here)**.
#
# This confirms that the model is functioning correctly and meets the project requirements.

# %% [markdown]
# ## Conclusion and Discussion

# %% [markdown]
# This project gave hands-on experience with natural language processing using real-world data.
# Improvements could include:
# - Testing other models like SVMs or neural networks
# - Using word embeddings (e.g., GloVe, BERT)
# - Better handling of noise in tweets (URLs, hashtags, etc.)
#
# The current implementation demonstrates a full pipeline from data to submission.
